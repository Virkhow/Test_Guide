# %% [markdown]
# <a href="https://colab.research.google.com/github/Virkhow/Test_Guide/blob/Upload-file/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# []

# %% [markdown]
# # Пример использования Markdown

# %% [markdown]
# Что нужно сделать:

# %% [markdown]
# 1. Список
# 2. Таблицу
# 3. Рисунок
# 4. Ссылку

# %% [markdown]
# ![1643626638_2-papik-pro-p-logotip-ngtu-2.png](data:image/png;base64,...)

# %% [markdown]
# A|B|C
# -|-|-
# 11|22|33
# 1000|250|-50

# %% [markdown]
# [Ссылка на руководство Markdown](https://colab.research.google.com/notebooks/markdown_guide.ipynb)

# %% [markdown]
# тест версий
